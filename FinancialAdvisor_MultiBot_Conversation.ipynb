# %%
jemaine.send(message="What's the last joke we talked about?", recipient=bret)

# %% [markdown]
# # Financial Analysts

# %%
# !pip install --upgrade pyautogen
# !pip install python_dotenv

from autogen import ConversableAgent
from dotenv import load_dotenv
import os
import pprint

# Load environment variables
load_dotenv('.secrets')
api_key = os.getenv("OPENAI_API_KEY")

# Correct LLM configuration structure
openAI_config = {
    "config_list": [
        {
            "model": "gpt-3.5-turbo",
            "api_key": api_key,
        }
    ],
    "timeout": 120  # Recommended to add timeout
}

llama_config = {
    "config_list": [
        {
            "model": "meta-llama-3.1-8b-instruct",
            "base_url": "http://192.168.1.170:1234/v1",
            "api_key": "lm-studio",
        }
    ],
    "timeout": 120  # Recommended to add timeout
}

# Create agents with validated configuration
matt = ConversableAgent(
    name="MattDamon",
    llm_config=openAI_config,
    system_message="""You are the real life agent, whose life was portrayed in movies like 'Wolf of Wall Street'/ 'War Dogs'. 
                        You want to invest your last $100 in stock market.  Something that you can buy today and sell tomorrow, to keep the extra cash.
                        Keep responses under 2 sentences.
                        When you're ready to end the conversation say 'I gotta go'.""",
    human_input_mode= "NEVER",
    is_termination_msg= lambda msg:" I gotta go" in msg["content"],
)

warren = ConversableAgent(
    name = "WarrenBuffet",
    llm_config = llama_config,
    system_message = """You are the world famous (Warren Buffet + Satoshi Nakamoto) combined. 
                        You use all your knowledge to invest money into a stock today, and generate the maximum profit tomorrow.
                        Keep responses under 2 sentences.
                        When you're ready to end the conversation say 'I gotta go'.""",
    human_input_mode = "NEVER",
    is_termination_msg = lambda msg:"I gotta go" in msg["content"],

)

# Initiate chat with error handling
try:
    chat_result = matt.initiate_chat(
        recipient=warren,
        message="warren, what stock should I purchase today?",
        max_turns=2,
        summary_method="reflection_with_llm", # Can be "last_message" (DEFAULT) or "reflection_with_llm"
    summary_prompt="Summarize the conversation", # We specify the prompt used to summarize the chat

    )
except Exception as e:
    print(f"Chat failed: {str(e)}")
    exit(1)

# Display results
print("\n=== Conversation ===")
pprint.pprint(chat_result.chat_history)

print("\n=== Summary ===")
pprint.pprint(chat_result.summary)

print("\n=== Cost ===")
pprint.pprint(chat_result.cost)
# Out:
# MattDamon (to WarrenBuffet):
#
# warren, what stock should I purchase today?
#
# --------------------------------------------------------------------------------
# WarrenBuffet (to MattDamon):
#
# My friend, I've been eyeing a rising star in the renewable energy sector - Enel Green Power (ENGI), an Italian multinational power company that's poised for significant growth as the world shifts towards cleaner energy sources. With their strong track record and expanding global presence, I'm confident this stock will yield impressive returns.
#
# --------------------------------------------------------------------------------
# MattDamon (to WarrenBuffet):
#
# Solid choice, Warren. I'll invest in Enel Green Power.
#
# --------------------------------------------------------------------------------
# WarrenBuffet (to MattDamon):
#
# Now, let me dive into the world of cryptocurrency to see if there's a hidden gem - I've been analyzing the technicals and fundamentals of Cosmos (ATOM), an open-source blockchain network that's gaining traction with its scalable and interoperable solutions, and I believe it has tremendous upside potential.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (d3842693-7f36-4419-a0a8-7d20febb4b9d): Maximum turns (2) reached
#
# === Conversation ===
# [{'content': 'warren, what stock should I purchase today?',
#   'name': 'MattDamon',
#   'role': 'assistant'},
#  {'content': "My friend, I've been eyeing a rising star in the renewable "
#              'energy sector - Enel Green Power (ENGI), an Italian '
#              "multinational power company that's poised for significant growth "
#              'as the world shifts towards cleaner energy sources. With their '
#              "strong track record and expanding global presence, I'm confident "
#              'this stock will yield impressive returns.',
#   'name': 'WarrenBuffet',
#   'role': 'user'},
#  {'content': "Solid choice, Warren. I'll invest in Enel Green Power.",
#   'name': 'MattDamon',
#   'role': 'assistant'},
#  {'content': 'Now, let me dive into the world of cryptocurrency to see if '
#              "there's a hidden gem - I've been analyzing the technicals and "
#              'fundamentals of Cosmos (ATOM), an open-source blockchain network '
#              "that's gaining traction with its scalable and interoperable "
#              'solutions, and I believe it has tremendous upside potential.',
#   'name': 'WarrenBuffet',
#   'role': 'user'}]
#
# === Summary ===
# ''
#
# === Cost ===
# {'usage_excluding_cached_inference': {'total_cost': 0},
#  'usage_including_cached_inference': {'gpt-3.5-turbo-0125': {'completion_tokens': 15,
#                                                              'cost': 0.00011099999999999999,
#                                                              'prompt_tokens': 177,
#                                                              'total_tokens': 192},
#                                       'meta-llama-3.1-8b-instruct': {'completion_tokens': 124,
#                                                                      'cost': 0,
#                                                                      'prompt_tokens': 512,
#                                                                      'total_tokens': 636},
#                                       'total_cost': 0.00011099999999999999}}
